# %% [markdown]
# # Credit Card Logistic Regression Project
#
# My goal for this project is to create a classifer using logistic regression that determines which observation from the artificial data set is fraudulent.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %% [markdown]
# ## Get the Data

# %%
data = pd.read_csv('creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(12,6))
data['Amount'].plot()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Class', data=data)

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# ## Standardize the Variables

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(data.drop('Class', axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(data.drop('Class', axis=1))

# %%
data_features = pd.DataFrame(scaled_features, columns=data.columns[:-1])
data_features = data_features.drop('Time', axis=1)
data_features
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068  0.193679
# 1       0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820 -0.063700
# 2      -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454  0.639776
# 3      -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150  0.192071
# 4      -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999  0.479302
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -6.065842  6.099286 -6.486245 -1.459641 -3.886611 -1.956690 -3.975628
# 284803 -0.374121 -0.033356  1.342145 -0.521651  0.629040  0.794446  0.019667
# 284804  0.980024 -0.182434 -2.143205 -0.393984  1.905833  2.275262 -0.239939
# 284805 -0.122755  0.321250  0.463320  0.487192 -0.273836  0.468155 -0.554672
# 284806 -0.272331 -0.114899  0.463866 -0.357570 -0.009089 -0.487602  1.274769
#
# ...

# %% [markdown]
# ## Using Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_features
y = data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# ## Predictions and Evaluations

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[85288    11]
#  [   56    88]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85299
#            1       0.89      0.61      0.72       144
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.81      0.86     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# Overall, the model is 94% accurate in separating accounts that are fradulent and not fradulent. The model is almost 100% accurate in predicting non-fradulent accounts, and about 89% accurate in predicting fradulent accounts.
